# %%
# !pip install PyYAML python-dotenv
# !pip install langchain langchain-community openai

# %%
import requests
import yaml
import os
from dotenv import load_dotenv
from langchain.prompts import PromptTemplate
from langchain.chat_models import AzureChatOpenAI
from tqdm import tqdm
from langchain.output_parsers import StructuredOutputParser, ResponseSchema
from langchain_core.exceptions import OutputParserException

# %%
# Load environment variables from .env file
load_dotenv()

# Azure OpenAI configuration from environment variables
endpoint = os.getenv("ENDPOINT_URL")
deployment = os.getenv("DEPLOYMENT_NAME")
subscription_key = os.getenv("AZURE_OPENAI_API_KEY")

# Verify that all required environment variables are present
if not all([endpoint, deployment, subscription_key]):
    raise ValueError("Missing required environment variables. Please check your .env file.")

# %%
# Configuration
USE_FILTERED_ACCOUNTS = True  # Set to False to process all accounts

# %%
def filter_repositories(accounts, target_repos):
    """
    Filter accounts to only include specified repositories.
    
    Args:
        accounts (dict): Dictionary of country to repository usernames
        target_repos (list): List of repository usernames to include
    
    Returns:
        dict: Filtered accounts containing only the specified repositories
    """
    filtered_accounts = {}
    for country, usernames in accounts.items():
        # Filter usernames that are in our target list
        filtered_usernames = [username for username in usernames if username in target_repos]
        if filtered_usernames:  # Only add countries that have matching repositories
            filtered_accounts[country] = filtered_usernames
    return filtered_accounts

# %%
# Define target repositories (example: UK government repositories)
TARGET_REPOS = [
    'alphagov', 'i-dot-ai', 'canada-ca', 'govtechsg', 'GSA', 'ec-europa', 'opengovsg'
]

# %%
def fetch_gov_github_accounts(url):
    response = requests.get(url)
    if response.status_code == 200:
        return yaml.safe_load(response.text)
    else:
        return None

def fetch_repository_details(username, token):
    headers = {'Authorization': f'token {token}'}
    repos_url = f"https://api.github.com/users/{username}/repos"
    repos_response = requests.get(repos_url, headers=headers)
    
    if repos_response.status_code == 200:
        repos_data = repos_response.json()
        full_repo_details = []
        
        for repo in repos_data:
            repo_details = {
                'name': repo['name'],
                'description': repo['description'] or "No description",
                'stars': repo['stargazers_count'],
                'forks': repo['forks'],
                'language': repo['language'] or "None specified"
            }
            # Fetch the README file
            readme_url = f"https://api.github.com/repos/{username}/{repo['name']}/readme"
            readme_response = requests.get(readme_url, headers=headers)
            if readme_response.status_code == 200:
                readme_data = readme_response.json()
                readme_content = requests.get(readme_data['download_url']).text
                repo_details['readme'] = readme_content[:100]  # Truncate for brevity
            else:
                repo_details['readme'] = "README not available"
            
            full_repo_details.append(repo_details)
        
        return full_repo_details
    else:
        return None

def save_to_markdown(repos, filename):
    with open(filename, 'w') as f:
        f.write('| Repository Name | Description | Stars | Language | README |\n')
        f.write('|-----------------|-------------|-------|----------|--------|\n')
        for repo in repos:
            f.write(f"| {repo['name']} | {repo['description']} | {repo['stars']} | {repo['language']} | {repo['readme'][:50]}... |\n")


# Load environment variables from .env file
load_dotenv('.env')

# Access environment variables
github_token = os.getenv('GITHUB_TOKEN')
if not github_token:
    raise ValueError("GITHUB_TOKEN not found in environment variables. Please check your .env file.")

# %%
# Main execution
url = "https://raw.githubusercontent.com/github/government.github.com/gh-pages/_data/governments.yml"
all_accounts = fetch_gov_github_accounts(url)

# %%
all_accounts
# Out:
# {'Argentina': ['argob',
#   'cifasis',
#   'gcba',
#   'inti-cmnb',
#   'municipalidad-de-vicente-lopez',
#   'municipioriogrande'],
#  'Australia': ['actesa',
#   'actgov',
#   'agnsw',
#   'AtlasOfLivingAustralia',
#   'ausdto',
#   'australianantarcticdatacentre',
#   'AustralianAntarcticDivision',
#   'berowrarfb',
#   'bom-radar',
#   'city-of-melbourne',
#   'commerce-wa-ols',
#   'consumerdataright',
#   'data61',
#   'datagovau',
#   'dbca-wa',
#   'dpc-sdp',
#   'dpipwe',
#   'dssgovaus',
#   'envris',
#   'Fire-and-Rescue-NSW',
#   'gccgisteam',
#   'GeoscienceAustralia',
#   'govau',
#   'govcms',
#   'gs-dawr',
#   'healthgovau',
#   'Healthway',
#   'hiscom',
#   'innovationgovau',
#   'IPAustralia',
#   'Landgate',
#   'nla',
#   'NSW-eTendering',
#   'NSWPlanning',
#   'pmcau',
#   'PublicRecordOfficeVictoria',
#   'qld-gov-au',
#   'srnsw',
#   'SunshineCoastCouncil',
#   'treasury-aus',
#   'victoriangovernment',
#   'wagov',
#   'wamuseum'],
#  'Austria': ['datagvat'],
#  'Belgium': ['belgianpolice',
#   'CIRB',
#   'Fedict',
#   'inbo',
#   'NationalBankBelgium',
#   'onroerenderfgoed',
#   'StadGent'],
#  'Bolivia': ['adsib', 'geobolivia'],
#  'Brazil': ['bacendeinf',
#   'camaradosdeputadosoficial',
#   'cenima-ibama',
#   'cislgov',
#   'culturagovbr',
#   'dadosgovbr',
#   'dataprev',
#   'EscolaDeSaudePublica',
#   'fablablivresp',
#   'fateczonaleste',
#   'gabinetedigital',
#   'govbr',
#   'GovBrasil',
#   'imagov',
#   'InstitutoBenjaminConstant',
#   'interlegis',
#   'justicagovbr',
#   'labhackercd',
#   'lexml',
#   'MP-ES',
#   'MP-RJ',
#   'pensandoodireito',
#   'plonegovbr',
#   'pr-snas',
#   'prefeitura-rio',
#   'prefeiturasp',
#   'PROCERGS',
#   'prodest',
#   'secom-tocantins',
#   'secultce',
#   'sepinf-inc',
#   'servicosgovbr',
#   'smcti',
#   'tcers',
#   'tisorocaba',
#   'tre-pa',
#   'wpgovbr'],
#  'Bulgaria': ['govbg', 'governmentbg'],
#  'Cambodia': ['e-Government-Cambodia'],
#  'Canada': ['AAFC-BICoE',
#   'abgov',
#   'asc-csa',
#   'bac-lac',
#   'BCGov',
#   'canada-ca',
#   'cds-snc',
#   'CityofEdmonton',
#   'cityofgreatersudbury',
#   'cityofottawa',
#   'CityOfSarnia',
#   'cityofsurrey',
#   'CityofToronto',
#   'cityssm',
#   'cngo',
#   'csbp-cpse',
#   'cse-cst',
#   'CSPS-EFPC-DAAN',
#   'CybercentreCanada',
#   'DTS-STN',
#   'ECCC-MSC',
#   'eodms-sgdot',
#   'esdc-devx',
#   'esdc-edsc',
#   'ExchangeBC',
#   'fgpv-vpgf',
#   'gc-proto',
#   'gcperformance',
#   'GCTC-NTGC',
#   'gctools-outilsgc',
#   'GeoCanViz',
#   'GNWT',
#   'GovAlta',
#   'infra-geo-ouverte',
#   'justicecanada',
#   'LMID-DIMT',
#   'MC-MBO-WebPublishingTeam',
#   'MetPX',
#   'nrc-cnrc',
#   'NRCan',
#   'nsgov',
#   'ongov',
#   'open-data',
#   'phac-aspc',
#   'phac-nml',
#   'PHACDataHub',
#   'pspc-spac',
#   'PSPC-SPAC-buyandsell',
#   'RAMP-PCAR',
#   'RDOQ',
#   'ServiceCanada',
#   'StatCan',
#   'TBS-EACPD',
#   'tc-ca',
#   'veteransaffairscanada',
#   'VilledeMontreal',
#   'wet-boew',
#   'ytgov'],
#  'Chile': ['e-gob'],
#  'China': ['CPPUer', 'PPSUCers'],
#  'Colombia': ['AltaConsejeriaTIC', 'evaluon', 'idu-bogota'],
#  'Czech Republic': ['MinistryOfJusticeCZ', 'NLCR', 'opendata-mvcr'],
#  'Denmark': ['kb-dk',
#   'Kortforsyningen',
#   'NationalMuseumofDenmark',
#   'Notalib',
#   'skat',
#   'ssi-dk',
#   'StatensMuseumforKunst'],
#  'Ecuador': ['inamhi', 'innovacionsnap', 'senescyt'],
#  'Egypt': ['informationtechnologyinstitute'],
#  'Estonia': ['e-gov', 'kinnisvara', 'MKM-ITAO', 'open-eid', 'opendata-ee'],
#  'Ethiopia': ['ethiopian'],
#  'European Union': ['digital-services-act',
#   'ec-europa',
#   'eea',
#   'eu-digital-green-certificates',
#   'eu-digital-identity-wallet',
#   'europarl',
#   'european-central-bank',
#   'europeana',
#   'openeuropa'],
#  'Finland': ['6Aika',
#   'City-of-Helsinki',
#   'City-of-Turku',
#   'CSC-IT-Center-for-Science',
#   'espoon-voltti',
#   'finnishtransportagency',
#   'Helsingin-kaupungin-tietokeskus',
#   'helsinki-city-library',
#   'HSLdevcom',
#   'Lounaispaikka',
#   'lukefi',
#   'NatLibFi',
#   'nlsfi',
#   'opetushallitus',
#   'sykefi',
#   'vrk-kpa'],
#  'France': ['afimb',
#   'AlsaceDigitale',
#   'AmbaNum',
#   'ansforge',
#   'ANSSI-FR',
#   'ApieFrance',
#   'atih',
#   'betagouv',
#   'BRGM',
#   'cea-hpc',
#   'cea-leti',
#   'cea-list',
#   'cea-sec',
#   'clipos',
#   'clipos-archive',
#   'communaute-cimi',
#   'culturecommunication',
#   'cw-leia',
#   'DGFiP',
#   'diplomatiegouvfr',
#   'disic',
#   'DREAL-NA',
#   'entrepreneur-interet-general',
#   'erasme',
#   'etalab',
#   'Inist-CNRS',
#   'InseeFr',
#   'lutece-secteur-public',
#   'MINAGRI-INITIAL',
#   'MinistereSupRecherche',
#   'MTES-MCT',
#   'nanterre',
#   'nantesmetropole',
#   'opencti-platform',
#   'PnCevennes',
#   'PnEcrins',
#   'PnX-SI',
#   'polewebmaedi',
#   'ProgrammeVitam',
#   'region-bretagne',
#   'sgmap-agd',
#   'SocialGouv',
#   'SocieteNumerique',
#   'strasbourg',
#   'wookey-project'],
#  'French Polynesia': ['sipf'],
#  'Germany': ['Basisvisualisierung',
#   'BSI-Bund',
#   'buehl',
#   'CERT-Bund',
#   'corona-warn-app',
#   'dbmdz',
#   'Digitaler-Impfnachweis',
#   'digitalservicebund',
#   'gbv',
#   'GovDataOfficial',
#   'hbz',
#   'isyfact',
#   'it-at-m',
#   'kdn-nrw',
#   'kreis-viersen',
#   'lobid',
#   'Oberverwaltungsgericht-Rheinland-Pfalz',
#   'OpenBfS',
#   'OpenNRW',
#   'regional-digital',
#   'robert-koch-institut',
#   'rostock',
#   'stadt-bielefeld',
#   'stadt-karlsruhe',
#   'StadtBruchsal',
#   'stadtulm'],
#  'Guatemala': ['minfingt'],
#  'Hong Kong': ['datagovhk'],
#  'Hungary': ['fphgov'],
#  'India': ['DataPortalIndia', 'ISRO', 'itschool', 'npci'],
#  'Indonesia': ['bolsel', 'jabardigitalservice', 'pemkab-rembang'],
#  'International': ['EL-BID', 'IATI', 'ogpl'],
#  'Ireland': ['HSEIreland', 'ogcio'],
#  'Isle of Man': ['Isle-Of-Man-Government'],
#  'Israel': ['CIOIL', 'Digital-Israel', 'MohGovIL', 'MostIL'],
#  'Italy': ['AgID',
#   'ComuneBologna',
#   'Formez',
#   'pcm-dpc',
#   'PloneGov-IT',
#   'RegioneER',
#   'TeamDigitale'],
#  'Japan': ['city-of-kobe',
#   'codefornamie',
#   'gsi-cyberjapan',
#   'nhohq',
#   'nims-dpfc'],
#  'Jersey': ['statesofjersey'],
#  'Kosovo': ['map-ashi'],
#  'Latvia': ['CSBLatvia'],
#  'Lithuania': ['AplinkosMinisterija',
#   'govlt',
#   'ivpk',
#   'KeliaukLietuvoje',
#   'Nacionaline-sporto-agentura',
#   'viesujupirkimutarnyba',
#   'vilnius',
#   'VMVT-DevHub'],
#  'Luxemburg': ['circl', 'Geoportail-Luxembourg', 'natliblux', 'opendatalu'],
#  'Malaysia': ['pmo2'],
#  'Mauritius': ['MUnosecc'],
#  'Mexico': ['CSB-IG',
#   'DDT-INMEGEN',
#   'IDEA-GTO',
#   'inmegen',
#   'LabLeon',
#   'mxabierto',
#   'PJECZ',
#   'profeco',
#   'redoaxacadetodos'],
#  'Netherlands': ['Amsterdam',
#   'dataoverheid',
#   'GemeenteAlmelo',
#   'GemeenteEde',
#   'Geonovum',
#   'Haarlem',
#   'IenS-Velsen',
#   'KBNLresearch',
#   'Logius-standaarden',
#   'MinBZK',
#   'MinELenI',
#   'minvws',
#   'Pleio',
#   'politie',
#   'provinciegroningen',
#   'provincieNH',
#   'StichtingHergebruikOverheid',
#   'TweedeKamer',
#   'zaanstad'],
#  'New Zealand': ['CanterburyRegionalCouncil',
#   'data-govt-nz',
#   'DigitalNZ',
#   'docgovtnz',
#   'ElectricityAuthority',
#   'GOVTNZ',
#   'linz',
#   'localgovernment',
#   'MfE-NZ',
#   'nz-social-investment-agency',
#   'opcnz',
#   'te-papa'],
#  'Norway': ['altinn',
#   'bergenkommune',
#   'brreg',
#   'danskernesdigitalebibliotek',
#   'difi',
#   'digibib',
#   'DirektoratetForByggkvalitet',
#   'dsb-norge',
#   'dss-web',
#   'kartverket',
#   'knreise',
#   'KRD-KOMM-VL',
#   'metno',
#   'miljodir',
#   'nasjonalmuseet',
#   'navikt',
#   'nlbdev',
#   'Nordland-fylkeskommune',
#   'politiet',
#   'Riksrevisjonen',
#   'Rogaland',
#   'rutebanken',
#   'ruterno',
#   'Skatteetaten',
#   'StatensPensjonskasse',
#   'statisticsnorway',
#   'telemark',
#   'telemark-arkiv',
#   'Tolletaten',
#   'uninett',
#   'vegvesen'],
#  'Panama': ['IFARHU', 'miambiente'],
#  'Paraguay': ['mecpy', 'SENATICS'],
#  'Peru': ['imarpe'],
#  'Philippines': ['corcueraromblon', 'govph', 'igovphil', 'Laoag-City'],
#  'Poland': ['coi-gov-pl', 'Ministerstwo-Cyfryzacji', 'nationalmuseum'],
#  'Portugal': ['amagovpt'],
#  'Republic of Korea': ['molit-korea'],
#  'Romania': ['govro', 'MinistryOfLabor'],
#  'Russia': ['cikrf', 'ghalghai', 'kznru', 'moscow-technologies'],
#  'Saudi Arabia': ['SAS-NCDC'],
#  'Singapore': ['dsaidgovsg', 'govtechsg', 'moexmen', 'opengovsg'],
#  'Slovakia': ['slovak-egov'],
#  'South Africa': ['eddZA'],
#  'Spain': ['AjMalgrat',
#   'AjuntamentdeBarcelona',
#   'AjuntamentdeCalafell',
#   'AjuntamentdeCastello',
#   'AjuntamentDeGava',
#   'AjuntamentDeMataro',
#   'AjuntamentdeReus',
#   'AjuntamentdeSabadell',
#   'AjuntamentdeSantCugat',
#   'AjuntamentdeTerrassa',
#   'AyuntamientoMadrid',
#   'ctt-gob-es',
#   'ErabakiPamplona',
#   'gencat',
#   'GobiernoLaRioja',
#   'HospitaletDeLlobregat',
#   'icane',
#   'lliurex',
#   'projectestac',
#   'vilanovailageltru'],
#  'Sweden': ['Alingsas-Kommun',
#   'arbetsformedlingen',
#   'domstol',
#   'dotse',
#   'elegnamnden',
#   'Forsakringskassan',
#   'gbif-sweden',
#   'Helsingborg',
#   'helsingborg-stad',
#   'ISOF-ITD',
#   'jobtechswe',
#   'kungbib',
#   'Lantmateriet',
#   'libris',
#   'lldd',
#   'lshSWE',
#   'malmostad',
#   'mtmse',
#   'NationalmuseumSWE',
#   'NordicMuseum',
#   'regionhalland',
#   'regionostergotland',
#   'riksantikvarieambetet',
#   'riksarkivet',
#   'rinfo',
#   'sambruk',
#   'SciLifeLab',
#   'SICS',
#   'skolverket',
#   'smhi',
#   'SodertornHB',
#   'statens-maritima-museer',
#   'statisticssweden',
#   'Sundsvallskommun',
#   'Sunet',
#   'sverigesradio',
#   'SVT',
#   'SwedenConnect',
#   'swedish-council-for-higher-education',
#   'swedishpensionsagency',
#   'The-Municipality-of-Staffanstorp',
#   'umea-kommun',
#   'Vastra-Gotalandsregionen',
#   'vasttrafik'],
#  'Switzerland': ['admin-ch',
#   'alv-ch',
#   'BFS-SHS-MSAS',
#   'dsi-vd',
#   'FNSKtZH',
#   'geoadmin',
#   'gisktzh',
#   'kanton-aargau',
#   'kanton-bern',
#   'metas-ch',
#   'ogdch',
#   'ogdtg',
#   'opendatabs',
#   'opendatazurich',
#   'openZH',
#   'SFOE',
#   'sitn',
#   'statistikstadtzuerich',
#   'statistikZH',
#   'VerkehrsbetriebeZuerich'],
#  'Taiwan': ['moda-gov-tw', 'pdis', 'taipei-doit', 'taipeicity'],
#  'Thailand': ['DGA-Thailand'],
#  'U.K. Central': ['111online',
#   'acteng',
#   'alphagov',
#   'BEACmodel',
#   'britishlibrary',
#   'cabinetoffice',
#   'CDPS-Wales',
#   'CJSCommonPlatform',
#   'co-cddo',
#   'communitiesuk',
#   'companieshouse',
#   'CPS-Innovation',
#   'datagovuk',
#   'datasciencecampus',
#   'decc',
#   'defra',
#   'DFE-Digital',
#   'dfid',
#   'digital-preservation',
#   'directgov-innovate',
#   'dstl',
#   'dvla',
#   'dvsa',
#   'dwp',
#   'GCHQ',
#   'gds-dead',
#   'gds-operations',
#   'govuk-one-login',
#   'guidance-guarantee-programme',
#   'hmcts',
#   'HMPO',
#   'hmrc',
#   'HO-CTO',
#   'houseofcommonslibrary',
#   'i-dot-ai',
#   'informatics-lab',
#   'insolvencyservice',
#   'intellectual-property-office',
#   'IQuOD',
#   'jncc',
#   'JNCC-UK',
#   'jules-lsm',
#   'LandRegistry',
#   'landregistry-ops',
#   'lgss',
#   'LocalGovDigital',
#   'MarineScotlandScience',
#   'MetOffice',
#   'MetOfficeSpaceApps',
#   'metomi',
#   'MHRA',
#   'ministryofjustice',
#   'moj-analytical-services',
#   'naouk',
#   'nationalarchives',
#   'NationalCrimeAgency',
#   'NationalLibraryOfScotland',
#   'nhsconnect',
#   'nhsdigital',
#   'nhsengland',
#   'nhsuk',
#   'NHSX',
#   'nice-digital',
#   'nihp-public',
#   'OfqualGovUK',
#   'ONSdigital',
#   'openregister',
#   'OrdnanceSurvey',
#   'osgeouk',
#   'scottishgovernment',
#   'SkillsFundingAgency',
#   'tanc-ahrc',
#   'ukforeignoffice',
#   'ukgovdatascience',
#   'UKGovernmentBEIS',
#   'UKHomeOffice',
#   'UKHomeOfficeForms',
#   'UKLocation',
#   'ukncsc',
#   'ukparliament',
#   'uktrade',
#   'ukwa'],
#  'U.K. Councils': ['BathnesDevelopment',
#   'BracknellForestCouncil',
#   'brighton-hove-gov-uk',
#   'BristolCityCouncil',
#   'CamdenCouncil',
#   'cityofyork',
#   'devoncc',
#   'DevonCountyCouncil',
#   'Dorset-Council-UK',
#   'DundeeCityCouncil',
#   'east-sussex-county-council',
#   'edinburghcouncil',
#   'essexcountycouncil',
#   'gmfrs',
#   'GuildfordBC',
#   'HfdsCouncil',
#   'kentcc',
#   'LambethCouncil',
#   'lichfield-district-council',
#   'LondonBoroughSutton',
#   'LutonCouncil',
#   'openglasgow',
#   'RoyalBoroughKingston',
#   'smbc-digital',
#   'surreydigitalservices',
#   'thehighlandcouncil',
#   'TraffordCouncil',
#   'warwickshire',
#   'wealden',
#   'west-berkshire-council',
#   'wmfs'],
#  'U.S. City': ['austincodeit',
#   'Baltimore-City-EGIS',
#   'berkeleypubliclibrary',
#   'BostonRedevelop',
#   'cambridgedata',
#   'cambridgegis',
#   'chicago',
#   'city-of-bellingham',
#   'city-of-bloomington',
#   'cityofasheville',
#   'CityOfAuburnAL',
#   'cityofaustin',
#   'cityofboise',
#   'CityOfBoston',
#   'cityofboulder',
#   'cityofburlington',
#   'cityofchattanooga',
#   'CityOfDetroit',
#   'CityOfLosAngeles',
#   'cityofnewyork',
#   'CityOfPhiladelphia',
#   'CityofPittsburgh',
#   'cityofportland',
#   'CityofReno',
#   'CityofSanFrancisco',
#   'CityofSantaMonica',
#   'cityofsomerville',
#   'cityofvernonia',
#   'CityOfVirginiaBeach',
#   'cityofwestsacramento',
#   'CityofYakima',
#   'cno-opa',
#   'CORaleigh',
#   'CUMTD',
#   'DCCouncil',
#   'DCgov',
#   'DenverDev',
#   'digitalinclusion',
#   'egovpdx',
#   'Honolulu',
#   'kcmo',
#   'lfucg',
#   'longbeachinnovationteam',
#   'LouisvilleMetro',
#   'louisvillemetro-innovation',
#   'mnhrc',
#   'mnylc',
#   'moda-nyc',
#   'monum',
#   'NewYorkCityCouncil',
#   'NYCComptroller',
#   'nycdot',
#   'NYCPlanning',
#   'onc-healthit',
#   'OpenGovDC',
#   'p2g',
#   'pdxgis',
#   'PierceCountyWA',
#   'ProBonoDC',
#   'ridertd',
#   'SantaClarita',
#   'sfbart',
#   'SiloamSprings',
#   'southbendin',
#   'TownOfBrookline',
#   'tucsonaz'],
#  'U.S. County': ['anoka-script-team',
#   'ArlingtonCounty',
#   'baltimorecounty',
#   'BayAreaMetro',
#   'bouldercounty',
#   'Canyon-County',
#   'CarverCounty',
#   'donaanacounty',
#   'fairfieldcountyit',
#   'fpdcc',
#   'HarrisCountyFOA',
#   'HennepinCountyPublicDefender',
#   'LACMTA',
#   'MCLD',
#   'pottcountyit',
#   'saccounty',
#   'sfcta',
#   'slugis'],
#  'U.S. Federal': ['18f',
#   'adl-aicc',
#   'adlnet',
#   'afrl',
#   'arcticlcc',
#   'BBGInnovate',
#   'bfelob',
#   'blue-button',
#   'businessusa',
#   'CA-CST-Library',
#   'CA-CST-SII',
#   'ccmc',
#   'CDCgov',
#   'cfpb',
#   'cigiegov',
#   'cisagov',
#   'cloud-gov',
#   'cmsgov',
#   'Code-dot-mil',
#   'commercedataservice',
#   'commercegov',
#   'demand-driven-open-data',
#   'department-of-veterans-affairs',
#   'dhs-gov',
#   'didsr',
#   'digital-analytics-program',
#   'dodcio',
#   'doecode',
#   'doi-open-data',
#   'EEOC',
#   'energyapps',
#   'erdc',
#   'eregs',
#   'FAA-Aviation-Data-Portal',
#   'fcc',
#   'fda',
#   'fecgov',
#   'Federal-Aviation-Administration',
#   'federal-courts-software-factory',
#   'federaltradecommission',
#   'fedramp',
#   'fedspendingtransparency',
#   'fema',
#   'firelab',
#   'globegit',
#   'gopleader',
#   'government-services',
#   'GrainGenes',
#   'gsa',
#   'gsa-oes',
#   'gsa-tts',
#   'hhs',
#   'HHS-AHRQ',
#   'HHSDigitalMediaAPIPlatform',
#   'HHSIDEAlab',
#   'historyatstate',
#   'IIP-Design',
#   'IMDProjects',
#   'imls',
#   'informaticslab',
#   'Innovation-Toolkit',
#   'internationaltradeadministration',
#   'ioos',
#   'IRSgov',
#   'keplergo',
#   'libraryofcongress',
#   'M-O-S-E-S',
#   'mcc-gov',
#   'missioncommand',
#   'nasa',
#   'nasa-develop',
#   'nasa-gibs',
#   'NASA-rdt',
#   'nasa-tournament-lab',
#   'nasaworldwind',
#   'NationalGuard',
#   'nationalparkservice',
#   'navadmc',
#   'NCI-Agency',
#   'NCRN',
#   'NeoGeographyToolkit',
#   'nesii',
#   'ngds',
#   'nhanes',
#   'nidcd',
#   'NIEM',
#   'NMB-Dev',
#   'NMML',
#   'NOAA-EPIC',
#   'noaa-gfdl',
#   'NOAA-ORR-ERD',
#   'noaa-pmel',
#   'ntia',
#   'NUWCDIVNPT',
#   'ombegov',
#   'Open-Sat',
#   'opengovplatform',
#   'ozoneplatform',
#   'peacecorps',
#   'petsc',
#   'presidential-innovation-fellows',
#   'project-open-data',
#   'radiofreeasia',
#   'redhawksdr',
#   'regulationsgov',
#   'sbstusa',
#   'SelectUSA',
#   'SERVIR',
#   'SSAgov',
#   'state-hiu',
#   'sunpy',
#   'us-bea',
#   'US-CBP',
#   'US-Department-of-the-Treasury',
#   'usagov',
#   'usaid',
#   'usasearch',
#   'usbr',
#   'uscensusbureau',
#   'uscis',
#   'usda',
#   'usda-ars-agil',
#   'usda-ars-gbru',
#   'usda-ars-ltar',
#   'usda-ars-nwrc',
#   'usda-ars-wmsru',
#   'USDA-ERS',
#   'USDA-FSA',
#   'usda-nifa-b-team',
#   'usda-vs',
#   'usdaForestService',
#   'usdepartmentoflabor',
#   'usdoj',
#   'usdot-fhwa-stol',
#   'usdot-jpo-ode',
#   'usds',
#   'useda',
#   'usepa',
#   'USFWS',
#   'usg-scope',
#   'USGCRP',
#   'usgpo',
#   'usgs',
#   'USGS-Astrogeology',
#   'usgs-cmg',
#   'usgs-eros',
#   'USGS-OWI',
#   'USGS-R',
#   'USGS-WiM',
#   'usnationalarchives',
#   'usopm',
#   'USPS',
#   'USPTO',
#   'USSBA',
#   'usstatedept',
#   'ustaxcourt',
#   'uswds',
#   'VHAINNOVATIONS',
#   'virtual-world-framework',
#   'visionworkbench',
#   'weather-gov',
#   'WFMRDA',
#   'whitehouse',
#   'XDgov'],
#  'U.S. Local Law Enforcement': ['SanDiegoCountySheriff'],
#  'U.S. Military and Intelligence': ['afseo',
#   'CRREL',
#   'deptofdefense',
#   'dod-cyber-crime-center',
#   'erdc-itl',
#   'iadgov',
#   'info-sharing-environment',
#   'NationalSecurityAgency',
#   'ngageoint',
#   'nsacyber',
#   'project-interoperability',
#   'psns-imf',
#   'shareandprotect',
#   'SIMP',
#   'transcom',
#   'usarmyresearchlab',
#   'USNavalResearchLaboratory'],
#  'U.S. Special District': ['atlregional',
#   'AZMAG',
#   'baaqmd',
#   'cleveland-metroparks',
#   'CMAP-REPOS',
#   'commonwealth-of-puerto-rico',
#   'MAPC',
#   'Metropolitan-Council',
#   'portofsandiego',
#   'psrc'],
#  'U.S. States': ['agrc',
#   'akhealth',
#   'azgs',
#   'cagov',
#   'CAWaterBoardDataCenter',
#   'ccap',
#   'CentralValleyModeling',
#   'coloradodemography',
#   'CTOpenData',
#   'DCGovWeb',
#   'eHawaii',
#   'FGS-FloridaGeologicalSurvey',
#   'gaepdit',
#   'gocodecolorado',
#   'IDAHO-DOC-NCOMS',
#   'idahofishgame',
#   'judicialcouncilcalifornia',
#   'la-ots',
#   'LADCO',
#   'LibraryofVA',
#   'massgov',
#   'MESMD',
#   'MFWP-GIS',
#   'nebraskamap',
#   'nelegislature',
#   'NJOGIS',
#   'njstatelibrary',
#   'ny',
#   'nys-its',
#   'nysenate',
#   'oimt',
#   'okcareertech',
#   'oregonopendata',
#   'ORMetro',
#   'scgeology',
#   'SLNC-DIMP',
#   'State-of-Arizona',
#   'StateOfCalifornia',
#   'swibwi',
#   'tndidd',
#   'TNRIS',
#   'twdb',
#   'TxDOT',
#   'UtahForestryFireStateLands',
#   'VDGIF',
#   'Virginia-Department-of-Health',
#   'Virginia-House-of-Delegates',
#   'vtrans',
#   'vtrans-rail',
#   'WA-Department-of-Agriculture',
#   'wsdot',
#   'WSDOT-GIS'],
#  'U.S. Tribal Nations': ['coquille-indian-tribe',
#   'MSBandofChoctawIndians',
#   'osage-nation'],
#  'Ukraine': ['openprocurement'],
#  'United Nations': ['GFDRR',
#   'OCHA-DAP',
#   'UN-ICC',
#   'UN-OCHA',
#   'uncefact',
#   'undp',
#   'unesco',
#   'UNGlobalPlatform',
#   'unicef',
#   'unido',
#   'UNStats',
#   'worldbank',
#   'WorldBank-Transport',
#   'WorldHealthOrganization'],
#  'Venezuela': ['CanaimaGNULinux', 'suscerte']}

# %%
# Choose whether to use filtered or all accounts
if USE_FILTERED_ACCOUNTS:
    print("Using filtered accounts...")
    accounts_to_process = filter_repositories(all_accounts, TARGET_REPOS)
else:
    print("Using all accounts...")
    accounts_to_process = all_accounts

# Process repositories
all_repos = []
if accounts_to_process:
    for country, usernames in accounts_to_process.items():
        print(f"Processing {len(usernames)} repositories for {country}")
        for username in usernames:
            print(f"Fetching data for {username}...")
            repo_details = fetch_repository_details(username, github_token)
            if repo_details:
                all_repos.extend(repo_details)
                print(f"Successfully processed {len(repo_details)} repositories for {username}")
            else:
                print(f"Failed to fetch data for {username}")

# Save results
if all_repos:
    # Choose appropriate filename based on whether we're using filtered accounts
    base_filename = "filtered_repositories" if USE_FILTERED_ACCOUNTS else "all_repositories"
    
    # Save as markdown
    markdown_file = f"{base_filename}.md"
    save_to_markdown(all_repos, markdown_file)
    print(f"\nResults saved to {markdown_file}")
    
    # Save as CSV
    import pandas as pd
    repos_df = pd.DataFrame(all_repos)
    csv_file = f"{base_filename}.csv"
    repos_df.to_csv(csv_file, index=False)
    print(f"Results also saved as {csv_file}")
else:
    print("No repository data collected.")
# Out:
# Using filtered accounts...
# Processing 1 repositories for Canada
# Fetching data for canada-ca...
# Successfully processed 30 repositories for canada-ca
# Processing 1 repositories for European Union
# Fetching data for ec-europa...
# Successfully processed 30 repositories for ec-europa
# Processing 2 repositories for Singapore
# Fetching data for govtechsg...
# Successfully processed 30 repositories for govtechsg
# Fetching data for opengovsg...
# Successfully processed 30 repositories for opengovsg
# Processing 2 repositories for U.K. Central
# Fetching data for alphagov...
# Successfully processed 30 repositories for alphagov
# Fetching data for i-dot-ai...
# Successfully processed 30 repositories for i-dot-ai
#
# Results saved to filtered_repositories.md
# Results also saved as filtered_repositories.csv

# %%
repos_df = pd.DataFrame(all_repos)
repos_df
# Out:
#                                  name  \
# 0                                a11y
# 1      accelerators_accelerateurs-aws
# 2    accelerators_accelerateurs-azure
# 3      accelerators_accelerateurs-gcp
# 4                             aia-eia
# ..                                ...
# 175                         lex-graph
# 176                    local-gov-hack
# 177           mvp-python-cookiecutter
# 178           platform-terraform-test
# 179                      redactomatic
#
#                                            description  stars  forks  \
# 0                                       No description      5      8
# 1    [AWS] Tools and templates to accelerate GC ser...     16      3
# 2    [AZURE] Tools and templates to accelerate GC s...     37     14
# 3    [GCP] Tools and templates to accelerate GC ser...     10      8
# 4    Algorithmic Impact Assessment - Évaluation de ...      3      2
# ..                                                 ...    ...    ...
# 175       Building a knowledge graph of UK legislation      8      1
# 176                                     No description     15      7
# 177   Unofficial cookiecutter for a basic Python repo.      0      0
# 178                                     No description      0      0
# 179  A Streamlit app for redacting documents with P...      4      1
#
#              language                                             readme
# 0                HTML  \n([Français](#gabarit-pour-dépôts-de-code-sou...
# 1      None specified  # GC Accelerators (AWS)\n\nAWS has developed a...
# 2          PowerShell  ([Français](#gc-accelerateurs-azure))\n\n## Az...
# 3                 HCL  \n# GC Accelerators (GCP)\n\n[![Open this proj...
# 4                HTML  [![Build Status](https://travis-ci.com/canada-...
# ..                ...                                                ...
# 175  Jupyter Notebook  # Lex Graph 🕸️\n[![PRs Welcome](https://img.sh...
# 176    None specified  # 🏙️ Local Government Innovation Hackathon\n\n...
# 177          Makefile  # Minimal Python Cookiecutter\n\nThis is a ver...
# 178               HCL  # I.AI Platform AWS / Terraform Exercise\n\n##...
# 179            Python  # Redact-o-matic\n\nA Streamlit app to help yo...
#
# [180 rows x 6 columns]

# %%
# !pip install langchain langchain-anthropic langchain-community

# %%
from langchain.prompts import PromptTemplate
from langchain_anthropic import ChatAnthropic
from tqdm import tqdm
from langchain.output_parsers import StructuredOutputParser, ResponseSchema
from langchain.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI
from langchain_core.exceptions import OutputParserException

anthropic_api_key = os.getenv('ANTHROPIC_KEY')
df = repos_df.copy()

def classify_repos(df, topic_list, model_name="gpt-4o"):
    # Initialize Azure OpenAI client
    llm = AzureChatOpenAI(
        openai_api_version="2025-01-01-preview",
        azure_deployment=deployment,
        azure_endpoint=endpoint,
        api_key=subscription_key,
    )
    
    summary_prompt = PromptTemplate(
        input_variables=["description", "readme"],
        template="""
        Please provide a summary of the following GitHub repository based on its description and README.md content. If the README.md is not in English, please first translate it to English and then generate a summary. The summary should be concise and in fewer than 5 sentences.
        
        Repository description:
        {description}
        
        README.md content:
        {readme}
        
        Summary:
        """
    )
    
    response_schemas = [
        ResponseSchema(name="topic", description="The selected topic for the repository.")
    ]
    output_parser = StructuredOutputParser.from_response_schemas(response_schemas)

    topic_prompt = PromptTemplate(
        input_variables=["summary", "topic_list"],
        template="""
        Given the following summary of a GitHub repository and a list of potential topics, select the most appropriate topic for the repository. If none of the topics in the list are suitable, generate a new topic label.

        Repository summary:
        {summary}

        Potential topics:
        {topic_list}

        Selected topic:
        {{topic}}

        PLEASE ONLY RETURN THE TOPIC LABEL AS THE RESPONSE. DO NOT INCLUDE ANY ADDITIONAL TEXT.
        """,
        output_parser=output_parser,
    )

    def generate_summary(row):
        description = row["description"] if pd.notnull(row["description"]) else ""
        readme = row["readme"] if pd.notnull(row["readme"]) else ""
        prompt = summary_prompt.format(description=description, readme=readme)
        summary = llm.invoke(prompt).content
        return summary

    def classify_repo(readme):
        row = df.loc[df["readme"] == readme].iloc[0]
        summary = generate_summary(row)
        prompt = topic_prompt.format(summary=summary, topic_list=", ".join(topic_list))
        response = llm.invoke(prompt).content

        try:
            topic = output_parser.parse(response)["topic"]
        except OutputParserException:
            # Handle the case when the response is not a valid JSON
            topic = response.strip()  # Extract the topic as a plain string

        if topic not in topic_list:
            topic_list.append(topic)

        return topic
    
    tqdm.pandas(desc="Classifying repositories")
    df["topic"] = df["readme"].progress_apply(classify_repo)
    
    df["summary"] = df.apply(generate_summary, axis=1)
    
    return df, topic_list

# %%
display(df)
# Out:
#                                  name  \
# 0                                a11y
# 1      accelerators_accelerateurs-aws
# 2    accelerators_accelerateurs-azure
# 3      accelerators_accelerateurs-gcp
# 4                             aia-eia
# ..                                ...
# 175                         lex-graph
# 176                    local-gov-hack
# 177           mvp-python-cookiecutter
# 178           platform-terraform-test
# 179                      redactomatic
#
#                                            description  stars  forks  \
# 0                                       No description      5      8
# 1    [AWS] Tools and templates to accelerate GC ser...     16      3
# 2    [AZURE] Tools and templates to accelerate GC s...     37     14
# 3    [GCP] Tools and templates to accelerate GC ser...     10      8
# 4    Algorithmic Impact Assessment - Évaluation de ...      3      2
# ..                                                 ...    ...    ...
# 175       Building a knowledge graph of UK legislation      8      1
# 176                                     No description     15      7
# 177   Unofficial cookiecutter for a basic Python repo.      0      0
# 178                                     No description      0      0
# 179  A Streamlit app for redacting documents with P...      4      1
#
#              language                                             readme
# 0                HTML  \n([Français](#gabarit-pour-dépôts-de-code-sou...
# 1      None specified  # GC Accelerators (AWS)\n\nAWS has developed a...
# 2          PowerShell  ([Français](#gc-accelerateurs-azure))\n\n## Az...
# 3                 HCL  \n# GC Accelerators (GCP)\n\n[![Open this proj...
# 4                HTML  [![Build Status](https://travis-ci.com/canada-...
# ..                ...                                                ...
# 175  Jupyter Notebook  # Lex Graph 🕸️\n[![PRs Welcome](https://img.sh...
# 176    None specified  # 🏙️ Local Government Innovation Hackathon\n\n...
# 177          Makefile  # Minimal Python Cookiecutter\n\nThis is a ver...
# 178               HCL  # I.AI Platform AWS / Terraform Exercise\n\n##...
# 179            Python  # Redact-o-matic\n\nA Streamlit app to help yo...
#
# [180 rows x 6 columns]

# %%
df, topic_list = classify_repos(repos_df, topic_list=['ai', 'web development', 'data science', 'cybersecurity'])
df
df.to_csv('all_gov_projects.csv', index=False)
# Out:
# /tmp/ipykernel_141209/54417327.py:14: LangChainDeprecationWarning: The class `AzureChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import AzureChatOpenAI``.
#   llm = AzureChatOpenAI(
# Classifying repositories: 100%|███████████████████████████████████████████████████████████████████████████████████| 180/180 [05:14<00:00,  1.75s/it]
